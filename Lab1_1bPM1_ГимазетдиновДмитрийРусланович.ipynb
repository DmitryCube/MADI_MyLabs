# %% [markdown]
# # Лабораторная работа №1
# ## Выполнил студент группы 1бПМ1 Гимазетдинов Дмитрий
# ### Задание №1
# Первая программа

# %%
print("Hello, world!")
# Out:
# Hello, world!

# %% [markdown]
# ## задание 2
# Написать генератор случайных матриц(многомерных), который принимает
# опциональные параметры m, n, min_limit, max_limit, где m и n указывают размер
# матрицы, а min_lim и max_lim - минимальное и максимальное значение для
# генерируемого числа . По умолчанию при отсутствии параметров принимать следующие
# значения:
# m = 50
# n = 50
# min_limit  = -250
# max_limit = 1000 + (номер своего варианта)

# %%
import random as rd

def random_matrix(m, n, min_limit, max_limit):
    dis = max_limit - min_limit + 1
    
    if (m == 1 or n == 1):
        # одномерный массив
        if (n == 1):
            mas = [0 for _ in range(m)];
            for i in range(m):
                mas[i] = rd.random() * dis - abs(min_limit)
        else:
            mas = [0 for _ in range(n)];
            for i in range(n):
                mas[i] = rd.random() * dis - abs(min_limit)

    else:
        # многомерный массив
        mas = [[0 for _ in range(m)] for _ in range(n)]

        for i in range(0, m):
            for j in range(0, n):
                mas[i][j] = rd.random() * dis - abs(min_limit) 
                
    return mas

m = 5
n = 5
min_lim = -250
max_lim = 1000 + 3


print(random_matrix(m, n, min_lim, max_lim))
# Out:
# [[276.42524541037426, 158.69874136718363, 878.7401027692997, 774.6178084612129, 824.4769621184953], [56.920936726795446, 730.0446469281682, 767.5806699692632, 453.1470707105789, 691.3342116328446], [627.6115242294809, 31.434393091731238, 765.6380899395433, 673.4821810314197, 657.3926136215865], [-245.50332129244208, 187.11168819279862, -38.42716067482718, -17.46840151225831, 154.7076326143303], [487.1323561130956, 777.1552552503792, 621.4218356258586, 226.28865270238305, 787.1553802494132]]

# %% [markdown]
# ## Задание 3
# Реализовать методы сортировки строк числовой матрицы в соответствии с
# заданием. Оценить время работы каждого алгоритма сортировки и сравнить его со
# временем стандартной функции сортировки. Испытания проводить на сгенерированных
# матрицах.

# %% [markdown]
# Сортировка выбором (одномерные массивы): сложность O(n²)

# %%
import random as rd

def random_matrix(m, n, min_limit, max_limit):
    dis = max_limit - min_limit + 1
    
    if (m == 1 or n == 1):
        # одномерный массив
        if (n == 1):
            mas = [0 for _ in range(m)];
            for i in range(m):
                mas[i] = rd.random() * dis - abs(min_limit)
        else:
            mas = [0 for _ in range(n)];
            for i in range(n):
                mas[i] = rd.random() * dis - abs(min_limit)

    else:
        # многомерный массив
        mas = [[0 for _ in range(m)] for _ in range(n)]

        for i in range(0, m):
            for j in range(0, n):
                mas[i][j] = rd.random() * dis - abs(min_limit) 
                
    return mas


def selection_sort(nums):  
    # Значение i = кол-ву отсортированных значений
    for i in range(len(nums)):
        # Исходно считаем наименьшим первый элемент
        lowest_index = i
        # Ищем наименьший элемент в оставшемся массиве
        for j in range(i + 1, len(nums)):
            if nums[j] < nums[lowest_index]:
                lowest_index = j
        # Элемент в i позиции меняем с наименьшим из оставшихся элементов
        nums[i], nums[lowest_index] = nums[lowest_index], nums[i]

# Проверка
random_matrix = random_matrix(1, 5, -10, 10)
selection_sort(random_matrix)  
print(random_matrix)
# Out:
# [-8.804267417516645, -1.9440683762699056, 4.685009902561918, 6.296482747902388, 8.48976234367229]

# %% [markdown]
# Сортировка вставками: сложность O(n²)

# %%
import random as rd

def random_matrix(m, n, min_limit, max_limit):
    dis = max_limit - min_limit + 1
    
    if (m == 1 or n == 1):
        # одномерный массив
        if (n == 1):
            mas = [0 for _ in range(m)];
            for i in range(m):
                mas[i] = rd.random() * dis - abs(min_limit)
        else:
            mas = [0 for _ in range(n)];
            for i in range(n):
                mas[i] = rd.random() * dis - abs(min_limit)

    else:
        # многомерный массив
        mas = [[0 for _ in range(m)] for _ in range(n)]

        for i in range(0, m):
            for j in range(0, n):
                mas[i][j] = rd.random() * dis - abs(min_limit) 
                
    return mas

def insertion(nums):
    for i in range(len(nums)):
        j = i - 1 
        key = nums[i]
        while nums[j] > key and j >= 0:
            # сдвиг больших элементов в сторону и поиск места
            nums[j + 1] = nums[j]
            j -= 1
        nums[j + 1] = key

# Проверка
random_matrix = random_matrix(1, 5, -10, 10)
insertion(random_matrix)  
print(random_matrix)
# Out:
# [-8.067297027222189, -5.945790521777956, 4.006900653655979, 8.682558437166506, 10.672353570151945]

# %% [markdown]
# Сортировка обменом(Пузырьковая): сложность O(n²)

# %%
import random as rd

def random_matrix(m, n, min_limit, max_limit):
    dis = max_limit - min_limit + 1
    
    if (m == 1 or n == 1):
        # одномерный массив
        if (n == 1):
            mas = [0 for _ in range(m)];
            for i in range(m):
                mas[i] = rd.random() * dis - abs(min_limit)
        else:
            mas = [0 for _ in range(n)];
            for i in range(n):
                mas[i] = rd.random() * dis - abs(min_limit)

    else:
        # многомерный массив
        mas = [[0 for _ in range(m)] for _ in range(n)]

        for i in range(0, m):
            for j in range(0, n):
                mas[i][j] = rd.random() * dis - abs(min_limit) 
                
    return mas

def bubble_sort(nums):  
    # isSorted - true -> массив остортирован, false -> массив не остортирован
    isSorted = False
    while not isSorted:
        isSorted = True
        for i in range(len(nums) - 1):
            if nums[i] > nums[i + 1]:
                # Меняем элементы
                nums[i], nums[i + 1] = nums[i + 1], nums[i]
                # Устанавливаем swapped в True для следующей итерации
                isSorted = False

# Проверка
random_matrix = random_matrix(1, 300, -100, 1000)
bubble_sort(random_matrix)  
print(random_matrix)
# Out:
# [-97.49840736385157, -94.62954739438005, -83.95805540221485, -83.40663654857899, -83.33867561975052, -82.19357075548609, -78.57487820873041, -78.49762070320165, -78.05345905475949, -71.33025556770936, -70.83622049475161, -62.76174362716385, -55.39923687222358, -46.59260323610642, -43.56311828312461, -42.710888835325285, -36.807229391489116, -33.74409136189773, -32.49693536129044, -31.635562965608116, -25.00940543313706, -23.490965322170908, -11.068957110027583, -6.9399584357834385, -6.216685056240394, -1.9155774080316235, 4.900750506908281, 9.111732126981977, 10.31474035378055, 14.30444927671482, 18.655946643546727, 24.301690368173723, 31.235360031244824, 34.21781505758338, 41.66975386052334, 45.93641762940925, 55.35872097729947, 55.68742293282099, 56.35618768685228, 57.03499144380575, 63.4373414041157, 64.9955678831499, 67.42862181661269, 68.05173928540259, 68.94993952448999, 71.66643402175833, 74.17955616889509, 77.56663937641, 82.94750257703066, 83.06100666473864, 84.4727149277286
# ...

# %% [markdown]
# Сортировка Шела: лучший случай O(n log2 n), худший случай O(n²)

# %%
import random as rd



def random_matrix(m, n, min_limit, max_limit):
    dis = max_limit - min_limit + 1
    
    if (m == 1 or n == 1):
        # одномерный массив
        if (n == 1):
            mas = [0 for _ in range(m)];
            for i in range(m):
                mas[i] = rd.random() * dis - abs(min_limit)
        else:
            mas = [0 for _ in range(n)];
            for i in range(n):
                mas[i] = rd.random() * dis - abs(min_limit)

    else:
        # многомерный массив
        mas = [[0 for _ in range(m)] for _ in range(n)]

        for i in range(0, m):
            for j in range(0, n):
                mas[i][j] = rd.random() * dis - abs(min_limit) 
                
    return mas


def shell(data):
    inc = len(data) // 2
    while inc:
        for i, el in enumerate(data):
            while i >= inc and data[i - inc] > el:
                data[i] = data[i - inc]
                i -= inc
            data[i] = el
        inc = 1 if inc == 2 else int(inc * 5.0 / 11)
    return data

# Проверка
random_matr = random_matrix(1, 50, -10, 10)
shell(random_matr)  
print(random_matr)
# Out:
# [-9.736094444319157, -9.174140436309527, -8.998336180768952, -8.28898724980851, -8.273635920507987, -7.807448933676805, -7.748614330456088, -7.357170174857705, -7.246049750374258, -5.99488222775059, -5.987646367089394, -5.378033043254516, -5.144367815170193, -5.104596200820747, -4.953590248289198, -4.880933557169159, -4.253884239386681, -4.07901591542006, -3.729592407009422, -3.4402563611707135, -1.8812927914662065, -1.732193731752675, -1.171238298547852, -0.4788657923497457, -0.4444164435064746, 0.9498553763310777, 1.3851273810986005, 1.9897827237446304, 2.502577477203749, 2.7039365001594398, 2.759450987714814, 2.8413689396819777, 3.2404635188861093, 4.350261662355736, 4.406293702367602, 4.679820768349176, 4.684196180480001, 4.993056384878688, 5.225917212883397, 5.233355571208531, 5.943779848209902, 6.460327879896916, 7.027182963937182, 7.454159811279116, 8.640028131283255, 9.386611815641206, 9.64555856865369, 9.807590696685214, 9.967138068489781, 10.931590356282712]

# %% [markdown]
# Пирамидальная сортировка: сложность O(n log n)

# %%
import random as rd

def random_matrix(m, n, min_limit, max_limit):
    dis = max_limit - min_limit + 1
    
    if (m == 1 or n == 1):
        # одномерный массив
        if (n == 1):
            mas = [0 for _ in range(m)];
            for i in range(m):
                mas[i] = rd.random() * dis - abs(min_limit)
        else:
            mas = [0 for _ in range(n)];
            for i in range(n):
                mas[i] = rd.random() * dis - abs(min_limit)

    else:
        # многомерный массив
        mas = [[0 for _ in range(m)] for _ in range(n)]

        for i in range(0, m):
            for j in range(0, n):
                mas[i][j] = rd.random() * dis - abs(min_limit) 
                
    return mas

# def createHeap(data, length, index):
#     largest = index
#     left = 2 * index + 1
#     right = 2 * index + 2
#     if left < length and data[index] < data[left]:
#         largest = left
#     if right < length and data[largest] < data[right]:
#         largest = right
#     if largest != index:
#         data[index], data[largest] = data[largest], data[index]
#         createHeap(data, length, largest)
        
# def heapSort(data):
#     length = len(data)
#     #We build max heap
#     for index in range(length, 0, -1): 
#         createHeap(data, length, index)
#     for index in range(length - 1, 0, -1):
#         data[index], data[0] = data[0], data[index]
#         createHeap(data, index, 0)
    
#     #print(data)
def heapify(nums, heap_size, root_index):  
    # Индекс наибольшего элемента считаем корневым индексом
    largest = root_index
    left_child = (2 * root_index) + 1
    right_child = (2 * root_index) + 2

    # Если левый потомок корня — допустимый индекс, а элемент больше,
    # чем текущий наибольший, обновляем наибольший элемент
    if left_child < heap_size and nums[left_child] > nums[largest]:
        largest = left_child

    # То же самое для правого потомка корня
    if right_child < heap_size and nums[right_child] > nums[largest]:
        largest = right_child

    # Если наибольший элемент больше не корневой, они меняются местами
    if largest != root_index:
        nums[root_index], nums[largest] = nums[largest], nums[root_index]
        # Heapify the new root element to ensure it's the largest
        heapify(nums, heap_size, largest)

def heap_sort(nums):  
    n = len(nums)

    # Создаём Max Heap из списка
    # Второй аргумент означает остановку алгоритма перед элементом -1, т.е.
    # перед первым элементом списка
    # 3-й аргумент означает повторный проход по списку в обратном направлении, 
    # уменьшая счётчик i на 1 
    for i in range(n, -1, -1):
        heapify(nums, n, i)

    # Перемещаем корень Max Heap в конец списка
    for i in range(n - 1, 0, -1):
        nums[i], nums[0] = nums[0], nums[i]
        heapify(nums, i, 0)

# Проверка
random_matrix = random_matrix(1, 10, -10, 10)
heap_sort(random_matrix) 
print(random_matrix)
# Out:
# [-7.9366680780538905, -5.0292543734380475, -0.9818771904526891, -0.4349779593567291, 3.480439730999894, 3.5091422915491375, 3.843830926254096, 5.417629099943454, 10.130672642493106, 10.34375999577739]

# %% [markdown]
# Быстрая сортировка:
# Разделяй и властвуй сложность O(n logn)

# %%
import random as rd

def random_matrix(m, n, min_limit, max_limit):
    dis = max_limit - min_limit + 1
    
    if (m == 1 or n == 1):
        # одномерный массив
        if (n == 1):
            mas = [0 for _ in range(m)];
            for i in range(m):
                mas[i] = rd.random() * dis - abs(min_limit)
        else:
            mas = [0 for _ in range(n)];
            for i in range(n):
                mas[i] = rd.random() * dis - abs(min_limit)

    else:
        # многомерный массив
        mas = [[0 for _ in range(m)] for _ in range(n)]

        for i in range(0, m):
            for j in range(0, n):
                mas[i][j] = rd.random() * dis - abs(min_limit) 
                
    return mas

def quicksort(array):
    if len(array) < 2:
        return array
    else:
        point = array[0]
        less = [i for i in array[1:] if i <= point]
        greater = [i for i in array[1:] if i > point]
        
        return quicksort(less) + [point] + quicksort(greater)
    
# Проверка
random_matrix = random_matrix(1, 5, -10, 10)
random_matrix = quicksort(random_matrix) 
print(random_matrix)
# Out:
# [-9.543972194657707, -8.193652076518502, -7.857777086931289, -0.7586491665374986, 9.597144701010325]

# %% [markdown]
# Сравнение сортировок:

# %%
import random as rd
import time as t

def quicksort(array):
    if len(array) < 2:
        return array
    else:
        point = array[0]
        less = [i for i in array[1:] if i <= point]
        greater = [i for i in array[1:] if i > point]
        
        return quicksort(less) + [point] + quicksort(greater)

def heapify(nums, heap_size, root_index):  
    # Индекс наибольшего элемента считаем корневым индексом
    largest = root_index
    left_child = (2 * root_index) + 1
    right_child = (2 * root_index) + 2

    # Если левый потомок корня — допустимый индекс, а элемент больше,
    # чем текущий наибольший, обновляем наибольший элемент
    if left_child < heap_size and nums[left_child] > nums[largest]:
        largest = left_child

    # То же самое для правого потомка корня
    if right_child < heap_size and nums[right_child] > nums[largest]:
        largest = right_child

    # Если наибольший элемент больше не корневой, они меняются местами
    if largest != root_index:
        nums[root_index], nums[largest] = nums[largest], nums[root_index]
        # Heapify the new root element to ensure it's the largest
        heapify(nums, heap_size, largest)

def heapSort(nums):  
    n = len(nums)

    # Создаём Max Heap из списка
    # Второй аргумент означает остановку алгоритма перед элементом -1, т.е.
    # перед первым элементом списка
    # 3-й аргумент означает повторный проход по списку в обратном направлении, 
    # уменьшая счётчик i на 1 
    for i in range(n, -1, -1):
        heapify(nums, n, i)

    # Перемещаем корень Max Heap в конец списка
    for i in range(n - 1, 0, -1):
        nums[i], nums[0] = nums[0], nums[i]
        heapify(nums, i, 0)

def shell(data):
    inc = len(data) // 2
    while inc:
        for i, el in enumerate(data):
            while i >= inc and data[i - inc] > el:
                data[i] = data[i - inc]
                i -= inc
            data[i] = el
        inc = 1 if inc == 2 else int(inc * 5.0 / 11)
    return data

def bubble_sort(nums):  
    # isSorted - true -> массив остортирован, false -> массив не остортирован
    isSorted = False
    while not isSorted:
        isSorted = True
        for i in range(len(nums) - 1):
            if nums[i] > nums[i + 1]:
                # Меняем элементы
                nums[i], nums[i + 1] = nums[i + 1], nums[i]
                # Устанавливаем swapped в True для следующей итерации
                isSorted = False

def insertion(nums):
    for i in range(len(nums)):
        j = i - 1 
        key = nums[i]
        while nums[j] > key and j >= 0:
            # сдвиг больших элементов в сторону и поиск места
            nums[j + 1] = nums[j]
            j -= 1
        nums[j + 1] = key

def selection_sort(nums):  
    # Значение i = кол-ву отсортированных значений
    for i in range(len(nums)):
        # Исходно считаем наименьшим первый элемент
        lowest_index = i
        # Ищем наименьший элемент в оставшемся массиве
        for j in range(i + 1, len(nums)):
            if nums[j] < nums[lowest_index]:
                lowest_index = j
        # Элемент в i позиции меняем с наименьшим из оставшихся элементов
        nums[i], nums[lowest_index] = nums[lowest_index], nums[i]

def random_matrix(m, n, min_limit, max_limit):
    dis = max_limit - min_limit + 1
    
    if (m == 1 or n == 1):
        # одномерный массив
        if (n == 1):
            mas = [0 for _ in range(m)];
            for i in range(m):
                mas[i] = rd.random() * dis - abs(min_limit)
        else:
            mas = [0 for _ in range(n)];
            for i in range(n):
                mas[i] = rd.random() * dis - abs(min_limit)

    else:
        # многомерный массив
        mas = [[0 for _ in range(m)] for _ in range(n)]

        for i in range(0, m):
            for j in range(0, n):
                mas[i][j] = rd.random() * dis - abs(min_limit) 
                
    return mas

# Сравнение времени выполнения
dataset = [random_matrix(1, 2 * i, -(i * 2), i * 2 ) for i in range(1000, 1050)];
times = [[0 for _ in range(7)] for _ in range(len(dataset))]
for i in range(len(dataset)):
    
    tmp = dataset[i]
    start_time = t.time()
    bubble_sort(tmp)    
    times[i][0] = round(t.time() - start_time, 6)

    start_time = t.time()
    insertion(tmp)
    times[i][1] = round(t.time() - start_time, 6)

    start_time = t.time()
    selection_sort(tmp)
    times[i][2] = round(t.time() - start_time, 6)

    start_time = t.time()
    shell(tmp)
    times[i][3] = round(t.time() - start_time, 6)

    start_time = t.time()
    heapSort(tmp)
    times[i][5] = t.time() - start_time

        
    try:    
        start_time = t.time()
        quicksort(tmp)
        times[i][6] = round(t.time() - start_time, 6)
    except:
        times[i][5] = "RecursionDepth"
        
    start_time = t.time()
    sorted(tmp)
    times[i][6] = round(t.time() - start_time, 6)
    
for i in range(len(times)):
    print(times[i])
# Out:
# [0.510386, 0.000311, 0.138731, 0.003598, 0, 0.01281881332397461, 4.2e-05]
# [0.57641, 0.000292, 0.148504, 0.00339, 0, 0.011478900909423828, 4.2e-05]
# [0.529147, 0.000339, 0.130023, 0.003119, 0, 0.010793447494506836, 4.1e-05]
# [0.540749, 0.000292, 0.15217, 0.004065, 0, 0.010731220245361328, 5.9e-05]
# [0.548737, 0.000349, 0.160979, 0.00528, 0, 0.018904447555541992, 3.9e-05]
# [0.542511, 0.000328, 0.144388, 0.00304, 0, 0.011986494064331055, 6e-05]
# [0.576808, 0.000344, 0.132244, 0.002634, 0, 0.012300729751586914, 4.1e-05]
# [0.584087, 0.000305, 0.159968, 0.002627, 0, 0.011240243911743164, 3.8e-05]
# [0.521792, 0.000299, 0.153188, 0.002636, 0, 0.01254582405090332, 3.8e-05]
# [0.54101, 0.000331, 0.134985, 0.002872, 0, 0.011746644973754883, 4e-05]
# [0.551672, 0.000309, 0.144293, 0.002548, 0, 0.01103973388671875, 4e-05]
# [0.564672, 0.000296, 0.144842, 0.003362, 0, 0.011859655380249023, 9.3e-05]
# [0.601605, 0.000548, 0.170701, 0.004709, 0, 0.014073610305786133, 3.9e-05]
# ...

# %% [markdown]
# Вывод: пузырьковая сортировка самая медленная, потом сортировка выборкой; пирамидальная и стандартная сортировка оказались самыми быстрыми.
